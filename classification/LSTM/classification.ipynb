# %% [markdown]
# # Predicting Satisfiability of SAT-3 Problems
# ## Solving the Classification Task using a ***Long Short-Term Memory (LSTM)***

# %% [markdown]
# A *satisfiability problem* (SAT problem) is a family of problems, where given a Boolean expression written using only the logical connectives AND, OR, NOT, variables and parentheses, we examine if there is some truth-assignment to the variables that will make the entire expression true. A **SAT-3** problem is a special case of SAT problem, where Boolean expression should have very strict form : the conjunctive normal form (CNF). A CNF is a conjunction of one or more clauses, where a clause is a disjunction of literals; otherwise put, it is an AND of ORs. In the SAT-3 problem, every disjunction consists of 3 literals. An example of a SAT-3 problem instance is the following:
# $$(x_1 \vee x_2 \vee \neg x_4) \wedge (\neg x_3 \vee x_4 \vee x_2)$$
#
# The SAT-3 problem is NP-complete and many solvers have been developed in order to prove the (un)satisfiability of the problems and point a truth assignment of the variables. However, not many large instances can be solved by traditional solvers and, thus, some researchers have come up with the idea to use Machine Learning methods in order to solve those problems, given that with the models we cannot have a guaranteed accuracy, but if the model generalizes well, then we would be able to solve some difficult problem-instances that the state-of-the-art solvers cannot.<br>
#
# In this assignment we will try predicting the satisfiability of the instances using a *Graph Transformer Network* and a *Long Short-Term Memory network (LSTM)*. In this notebook will be explained the process of using a LSTM.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import random
__counter__ = random.randint(0,2e9)

from IPython.display import HTML, display

# %%
import os, shutil
import json

from tuning import tune_parameters
from data_loader import dataset_processing
from train import training, testing
# Out:
# Device is: cuda:0

# %% [markdown]
# ### Training and Evaluation process

# %% [markdown]
# In order to train the model, a *training set* is used alongside with a *validation set*. The latter is used to measure the performance of the model. The training and validation set were extracted from the 80% (60%-20%) of the data and the rest 20% was kept to evaluate the model after its training (*test set*).

# %% [markdown]
# **Create the dataset**: The dataset is created from the raw data in such a format that it can be loader by the *DataLoader* module of torch.utils.data. <br>
#
# In this case, the data was treated as *timeseries* with sequence length equal to 2. In order for that to be able to happen, some data augmentation was performed. Specifically, as noted by the dataset documentation (<a href="https://www.cs.ubc.ca/~hoos/SATLIB/Benchmarks/SAT/RND3SAT/descr.html">Dataset Documentation</a>), for all problem instances there is a clause number-threshold after which the problem is highly unlikely to be satisfiable. So, before this threshold, the problem is most likely to be satisfiable and, for that reason, it is possible to augment the dataset in two ways :
# <ol>
#     <li>For each instance provide a satisfiable smaller version of it (the instance below the threshold).</li>
#     <li>For each unsatisfiable instance provide another unsatisfiable instance (the instance just above the threshold).</li>
# </ol>

# %%
pos_weight = dataset_processing()
# Out:
# Start the data processing...
#
# Satisfiable CNFs   : 7402
# Unsatisfiable CNFs : 5154
#
# Ratio of SAT   : 0.5895
# Ratio of UNSAT : 0.4105
#
# Training set size: 11275
# Validation set size: 1410
# Test set size: 1407
#
# Processing completed.

# %% [markdown]
# It should be noted that the LSTM model needs about 300 times more data that its parameters and in our case we have 970561 parameters and 14092 input data. **Thus, due to the amount of data, even after the augmentation, the model is not expected to reach high values in the evaluation metrics**.

# %% [markdown]
# **Tune parameters**: Tune the parameters of the model (LSTM itself) as well as parameters regarding the training process e.g. *batch-size*, *weight decay* etc. More specidically, the parameters that are tuned are the following.
# <ol><li>Model parameters:</li>
#     <ul>
#         <li>Number of layers</li>
#         <li>Dropout rate</li>
#         <li>Hidden Units</li><br>
#     </ul>
#     <li>Training parameters:</li>
#     <ul>
#         <li>Batch size used</li>
#         <li>Learning rate</li>
#         <li>Weight decay</li>
#     </ul>
# </ol>

# %% [markdown]
# The parameters of the final model are the ones that result in the minimum ***validation error***. <br>
# Also, ***early stopping*** is used in order to avoid *overfitting*.

# %%
# Tune parameters
best_parameters = tune_parameters(pos_weight=pos_weight)

# Show best parameters
print(f'\nBest hyperparameters were: {best_parameters}\n')
# Store best parameters
with open('./best_parameters_same_sets.txt', 'w') as f:
    f.write(json.dumps(best_parameters))

f.close()
# Out:
# Test number 1 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 102889
#
# EPOCH | 0
# Training Loss   : 0.5716
# Validation Loss : 0.5788
#
# EPOCH | 1
# Training Loss   : 0.5710
# Validation Loss : 0.5791
#
# EPOCH | 2
# Training Loss   : 0.5685
# Validation Loss : 0.5769
#
# EPOCH | 3
# Training Loss   : 0.5665
# Validation Loss : 0.5692
#
# EPOCH | 4
# Training Loss   : 0.5620
# Validation Loss : 0.5730
#
# EPOCH | 5
# Training Loss   : 0.5597
# Validation Loss : 0.5733
#
# EPOCH | 6
# Training Loss   : 0.5523
# Validation Loss : 0.5643
#
# EPOCH | 7
# Training Loss   : 0.5466
# Validation Loss : 0.5908
#
# EPOCH | 8
# Training Loss   : 0.5397
# Validation Loss : 0.5674
#
# EPOCH | 9
# Training Loss   : 0.5282
# Validation Loss : 0.5813
#
# EPOCH | 10
# Training Loss   : 0.5179
# Validation Loss : 0.5862
#
# EPOCH | 11
# Training Loss   : 0.4965
# Validation Loss : 0.5967
#
# EPOCH | 12
# Training Loss   : 0.4767
# Validation Loss : 0.6203
#
# EPOCH | 13
# Training Loss   : 0.4458
# Validation Loss : 0.6600
#
# EPOCH | 14
# Early stopping activated, with training and validation loss difference: 0.0027
# New best parameters found!
#
#
# Test number 2 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 102889
#
# EPOCH | 0
# Training Loss   : 0.5704
# Validation Loss : 0.5744
#
# EPOCH | 1
# Training Loss   : 0.5671
# Validation Loss : 0.5714
#
# EPOCH | 2
# Training Loss   : 0.5667
# Validation Loss : 0.5725
#
# EPOCH | 3
# Training Loss   : 0.5661
# Validation Loss : 0.5832
#
# EPOCH | 4
# Training Loss   : 0.5628
# Validation Loss : 0.5760
#
# EPOCH | 5
# Training Loss   : 0.5571
# Validation Loss : 0.5632
#
# EPOCH | 6
# Training Loss   : 0.5531
# Validation Loss : 0.5726
#
# EPOCH | 7
# Training Loss   : 0.5469
# Validation Loss : 0.5806
#
# EPOCH | 8
# Training Loss   : 0.5389
# Validation Loss : 0.5836
#
# EPOCH | 9
# Training Loss   : 0.5248
# Validation Loss : 0.5831
#
# EPOCH | 10
# Training Loss   : 0.5165
# Validation Loss : 0.5910
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.0040
#
# Test number 3 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 102889
#
# EPOCH | 0
# Training Loss   : 0.5704
# Validation Loss : 0.5744
#
# EPOCH | 1
# Training Loss   : 0.5671
# Validation Loss : 0.5714
#
# EPOCH | 2
# Training Loss   : 0.5667
# Validation Loss : 0.5725
#
# EPOCH | 3
# Training Loss   : 0.5661
# Validation Loss : 0.5832
#
# EPOCH | 4
# Training Loss   : 0.5628
# Validation Loss : 0.5760
#
# EPOCH | 5
# Training Loss   : 0.5571
# Validation Loss : 0.5632
#
# EPOCH | 6
# Training Loss   : 0.5531
# Validation Loss : 0.5726
#
# EPOCH | 7
# Training Loss   : 0.5469
# Validation Loss : 0.5806
#
# EPOCH | 8
# Training Loss   : 0.5389
# Validation Loss : 0.5836
#
# EPOCH | 9
# Training Loss   : 0.5248
# Validation Loss : 0.5831
#
# EPOCH | 10
# Training Loss   : 0.5165
# Validation Loss : 0.5910
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.0040
#
# Test number 4 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 102889
#
# EPOCH | 0
# Training Loss   : 0.5704
# Validation Loss : 0.5744
#
# EPOCH | 1
# Training Loss   : 0.5671
# Validation Loss : 0.5714
#
# EPOCH | 2
# Training Loss   : 0.5667
# Validation Loss : 0.5725
#
# EPOCH | 3
# Training Loss   : 0.5661
# Validation Loss : 0.5832
#
# EPOCH | 4
# Training Loss   : 0.5628
# Validation Loss : 0.5760
#
# EPOCH | 5
# Training Loss   : 0.5571
# Validation Loss : 0.5632
#
# EPOCH | 6
# Training Loss   : 0.5531
# Validation Loss : 0.5726
#
# EPOCH | 7
# Training Loss   : 0.5469
# Validation Loss : 0.5806
#
# EPOCH | 8
# Training Loss   : 0.5389
# Validation Loss : 0.5836
#
# EPOCH | 9
# Training Loss   : 0.5248
# Validation Loss : 0.5831
#
# EPOCH | 10
# Training Loss   : 0.5165
# Validation Loss : 0.5910
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.0040
#
# Test number 5 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 104041
#
# EPOCH | 0
# Training Loss   : 0.5709
# Validation Loss : 0.5688
#
# EPOCH | 1
# Training Loss   : 0.5679
# Validation Loss : 0.5760
#
# EPOCH | 2
# Training Loss   : 0.5670
# Validation Loss : 0.5757
#
# EPOCH | 3
# Training Loss   : 0.5654
# Validation Loss : 0.5671
#
# EPOCH | 4
# Training Loss   : 0.5639
# Validation Loss : 0.5631
#
# EPOCH | 5
# Training Loss   : 0.5603
# Validation Loss : 0.5810
#
# EPOCH | 6
# Training Loss   : 0.5525
# Validation Loss : 0.5661
#
# EPOCH | 7
# Training Loss   : 0.5477
# Validation Loss : 0.5778
#
# EPOCH | 8
# Training Loss   : 0.5401
# Validation Loss : 0.5721
#
# EPOCH | 9
# Training Loss   : 0.5302
# Validation Loss : 0.5888
#
# EPOCH | 10
# Training Loss   : 0.5182
# Validation Loss : 0.6114
#
# EPOCH | 11
# Training Loss   : 0.5002
# Validation Loss : 0.6008
#
# EPOCH | 12
# Training Loss   : 0.4770
# Validation Loss : 0.6238
#
# EPOCH | 13
# Training Loss   : 0.4483
# Validation Loss : 0.6413
#
# EPOCH | 14
# Training Loss   : 0.4113
# Validation Loss : 0.6932
#
# EPOCH | 15
# Early stopping activated, with training and validation loss difference: 0.0008
# New best parameters found!
#
#
# Test number 6 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 104041
#
# EPOCH | 0
# Training Loss   : 0.5709
# Validation Loss : 0.5688
#
# EPOCH | 1
# Training Loss   : 0.5679
# Validation Loss : 0.5760
#
# EPOCH | 2
# Training Loss   : 0.5670
# Validation Loss : 0.5757
#
# EPOCH | 3
# Training Loss   : 0.5654
# Validation Loss : 0.5671
#
# EPOCH | 4
# Training Loss   : 0.5639
# Validation Loss : 0.5631
#
# EPOCH | 5
# Training Loss   : 0.5603
# Validation Loss : 0.5810
#
# EPOCH | 6
# Training Loss   : 0.5525
# Validation Loss : 0.5661
#
# EPOCH | 7
# Training Loss   : 0.5477
# Validation Loss : 0.5778
#
# EPOCH | 8
# Training Loss   : 0.5401
# Validation Loss : 0.5721
#
# EPOCH | 9
# Training Loss   : 0.5302
# Validation Loss : 0.5888
#
# EPOCH | 10
# Training Loss   : 0.5182
# Validation Loss : 0.6114
#
# EPOCH | 11
# Training Loss   : 0.5002
# Validation Loss : 0.6008
#
# EPOCH | 12
# Training Loss   : 0.4770
# Validation Loss : 0.6238
#
# EPOCH | 13
# Training Loss   : 0.4483
# Validation Loss : 0.6413
#
# EPOCH | 14
# Training Loss   : 0.4113
# Validation Loss : 0.6932
#
# EPOCH | 15
# Early stopping activated, with training and validation loss difference: 0.0008
#
# Test number 7 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 104041
#
# EPOCH | 0
# Training Loss   : 0.5709
# Validation Loss : 0.5688
#
# EPOCH | 1
# Training Loss   : 0.5679
# Validation Loss : 0.5760
#
# EPOCH | 2
# Training Loss   : 0.5670
# Validation Loss : 0.5757
#
# EPOCH | 3
# Training Loss   : 0.5654
# Validation Loss : 0.5671
#
# EPOCH | 4
# Training Loss   : 0.5639
# Validation Loss : 0.5631
#
# EPOCH | 5
# Training Loss   : 0.5603
# Validation Loss : 0.5810
#
# EPOCH | 6
# Training Loss   : 0.5525
# Validation Loss : 0.5661
#
# EPOCH | 7
# Training Loss   : 0.5477
# Validation Loss : 0.5778
#
# EPOCH | 8
# Training Loss   : 0.5401
# Validation Loss : 0.5721
#
# EPOCH | 9
# Training Loss   : 0.5302
# Validation Loss : 0.5888
#
# EPOCH | 10
# Training Loss   : 0.5182
# Validation Loss : 0.6114
#
# EPOCH | 11
# Training Loss   : 0.5002
# Validation Loss : 0.6008
#
# EPOCH | 12
# Training Loss   : 0.4770
# Validation Loss : 0.6238
#
# EPOCH | 13
# Training Loss   : 0.4483
# Validation Loss : 0.6413
#
# EPOCH | 14
# Training Loss   : 0.4113
# Validation Loss : 0.6932
#
# EPOCH | 15
# Early stopping activated, with training and validation loss difference: 0.0008
#
# Test number 8 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 104041
#
# EPOCH | 0
# Training Loss   : 0.5709
# Validation Loss : 0.5688
#
# EPOCH | 1
# Training Loss   : 0.5679
# Validation Loss : 0.5760
#
# EPOCH | 2
# Training Loss   : 0.5670
# Validation Loss : 0.5757
#
# EPOCH | 3
# Training Loss   : 0.5654
# Validation Loss : 0.5671
#
# EPOCH | 4
# Training Loss   : 0.5639
# Validation Loss : 0.5631
#
# EPOCH | 5
# Training Loss   : 0.5603
# Validation Loss : 0.5810
#
# EPOCH | 6
# Training Loss   : 0.5525
# Validation Loss : 0.5661
#
# EPOCH | 7
# Training Loss   : 0.5477
# Validation Loss : 0.5778
#
# EPOCH | 8
# Training Loss   : 0.5401
# Validation Loss : 0.5721
#
# EPOCH | 9
# Training Loss   : 0.5302
# Validation Loss : 0.5888
#
# EPOCH | 10
# Training Loss   : 0.5182
# Validation Loss : 0.6114
#
# EPOCH | 11
# Training Loss   : 0.5002
# Validation Loss : 0.6008
#
# EPOCH | 12
# Training Loss   : 0.4770
# Validation Loss : 0.6238
#
# EPOCH | 13
# Training Loss   : 0.4483
# Validation Loss : 0.6413
#
# EPOCH | 14
# Training Loss   : 0.4113
# Validation Loss : 0.6932
#
# EPOCH | 15
# Early stopping activated, with training and validation loss difference: 0.0008
#
# Test number 9 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 105193
#
# EPOCH | 0
# Training Loss   : 0.5705
# Validation Loss : 0.5709
#
# EPOCH | 1
# Training Loss   : 0.5681
# Validation Loss : 0.5783
#
# EPOCH | 2
# Training Loss   : 0.5672
# Validation Loss : 0.5801
#
# EPOCH | 3
# Training Loss   : 0.5658
# Validation Loss : 0.5683
#
# EPOCH | 4
# Training Loss   : 0.5635
# Validation Loss : 0.5774
#
# EPOCH | 5
# Training Loss   : 0.5589
# Validation Loss : 0.5828
#
# EPOCH | 6
# Training Loss   : 0.5530
# Validation Loss : 0.5691
#
# EPOCH | 7
# Training Loss   : 0.5450
# Validation Loss : 0.5716
#
# EPOCH | 8
# Training Loss   : 0.5375
# Validation Loss : 0.5817
#
# EPOCH | 9
# Training Loss   : 0.5279
# Validation Loss : 0.5791
#
# EPOCH | 10
# Training Loss   : 0.5094
# Validation Loss : 0.6017
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.0004
#
# Test number 10 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 105193
#
# EPOCH | 0
# Training Loss   : 0.5705
# Validation Loss : 0.5709
#
# EPOCH | 1
# Training Loss   : 0.5681
# Validation Loss : 0.5783
#
# EPOCH | 2
# Training Loss   : 0.5672
# Validation Loss : 0.5801
#
# EPOCH | 3
# Training Loss   : 0.5658
# Validation Loss : 0.5683
#
# EPOCH | 4
# Training Loss   : 0.5635
# Validation Loss : 0.5774
#
# EPOCH | 5
# Training Loss   : 0.5589
# Validation Loss : 0.5828
#
# EPOCH | 6
# Training Loss   : 0.5530
# Validation Loss : 0.5691
#
# EPOCH | 7
# Training Loss   : 0.5450
# Validation Loss : 0.5716
#
# EPOCH | 8
# Training Loss   : 0.5375
# Validation Loss : 0.5817
#
# EPOCH | 9
# Training Loss   : 0.5279
# Validation Loss : 0.5791
#
# EPOCH | 10
# Training Loss   : 0.5094
# Validation Loss : 0.6017
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.0004
#
# Test number 11 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 105193
#
# EPOCH | 0
# Training Loss   : 0.5705
# Validation Loss : 0.5709
#
# EPOCH | 1
# Training Loss   : 0.5681
# Validation Loss : 0.5783
#
# EPOCH | 2
# Training Loss   : 0.5672
# Validation Loss : 0.5801
#
# EPOCH | 3
# Training Loss   : 0.5658
# Validation Loss : 0.5683
#
# EPOCH | 4
# Training Loss   : 0.5635
# Validation Loss : 0.5774
#
# EPOCH | 5
# Training Loss   : 0.5589
# Validation Loss : 0.5828
#
# EPOCH | 6
# Training Loss   : 0.5530
# Validation Loss : 0.5691
#
# EPOCH | 7
# Training Loss   : 0.5450
# Validation Loss : 0.5716
#
# EPOCH | 8
# Training Loss   : 0.5375
# Validation Loss : 0.5817
#
# EPOCH | 9
# Training Loss   : 0.5279
# Validation Loss : 0.5791
#
# EPOCH | 10
# Training Loss   : 0.5094
# Validation Loss : 0.6017
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.0004
#
# Test number 12 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 105193
#
# EPOCH | 0
# Training Loss   : 0.5705
# Validation Loss : 0.5709
#
# EPOCH | 1
# Training Loss   : 0.5681
# Validation Loss : 0.5783
#
# EPOCH | 2
# Training Loss   : 0.5672
# Validation Loss : 0.5801
#
# EPOCH | 3
# Training Loss   : 0.5658
# Validation Loss : 0.5683
#
# EPOCH | 4
# Training Loss   : 0.5635
# Validation Loss : 0.5774
#
# EPOCH | 5
# Training Loss   : 0.5589
# Validation Loss : 0.5828
#
# EPOCH | 6
# Training Loss   : 0.5530
# Validation Loss : 0.5691
#
# EPOCH | 7
# Training Loss   : 0.5450
# Validation Loss : 0.5716
#
# EPOCH | 8
# Training Loss   : 0.5375
# Validation Loss : 0.5817
#
# EPOCH | 9
# Training Loss   : 0.5279
# Validation Loss : 0.5791
#
# EPOCH | 10
# Training Loss   : 0.5094
# Validation Loss : 0.6017
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.0004
#
# Test number 13 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 206289
#
# EPOCH | 0
# Training Loss   : 0.5733
# Validation Loss : 0.5686
#
# EPOCH | 1
# Training Loss   : 0.5696
# Validation Loss : 0.5787
#
# EPOCH | 2
# Training Loss   : 0.5669
# Validation Loss : 0.5753
#
# EPOCH | 3
# Training Loss   : 0.5646
# Validation Loss : 0.5868
#
# EPOCH | 4
# Training Loss   : 0.5618
# Validation Loss : 0.5668
#
# EPOCH | 5
# Training Loss   : 0.5631
# Validation Loss : 0.5784
#
# EPOCH | 6
# Training Loss   : 0.5546
# Validation Loss : 0.5830
#
# EPOCH | 7
# Training Loss   : 0.5482
# Validation Loss : 0.5767
#
# EPOCH | 8
# Training Loss   : 0.5405
# Validation Loss : 0.5781
#
# EPOCH | 9
# Training Loss   : 0.5321
# Validation Loss : 0.5905
#
# EPOCH | 10
# Training Loss   : 0.5199
# Validation Loss : 0.5999
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.0046
#
# Test number 14 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 206289
#
# EPOCH | 0
# Training Loss   : 0.5733
# Validation Loss : 0.5686
#
# EPOCH | 1
# Training Loss   : 0.5696
# Validation Loss : 0.5787
#
# EPOCH | 2
# Training Loss   : 0.5669
# Validation Loss : 0.5753
#
# EPOCH | 3
# Training Loss   : 0.5646
# Validation Loss : 0.5868
#
# EPOCH | 4
# Training Loss   : 0.5618
# Validation Loss : 0.5668
#
# EPOCH | 5
# Training Loss   : 0.5631
# Validation Loss : 0.5784
#
# EPOCH | 6
# Training Loss   : 0.5546
# Validation Loss : 0.5830
#
# EPOCH | 7
# Training Loss   : 0.5482
# Validation Loss : 0.5767
#
# EPOCH | 8
# Training Loss   : 0.5405
# Validation Loss : 0.5781
#
# EPOCH | 9
# Training Loss   : 0.5321
# Validation Loss : 0.5905
#
# EPOCH | 10
# Training Loss   : 0.5199
# Validation Loss : 0.5999
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.0046
#
# Test number 15 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 206289
#
# EPOCH | 0
# Training Loss   : 0.5733
# Validation Loss : 0.5686
#
# EPOCH | 1
# Training Loss   : 0.5696
# Validation Loss : 0.5787
#
# EPOCH | 2
# Training Loss   : 0.5669
# Validation Loss : 0.5753
#
# EPOCH | 3
# Training Loss   : 0.5646
# Validation Loss : 0.5868
#
# EPOCH | 4
# Training Loss   : 0.5618
# Validation Loss : 0.5668
#
# EPOCH | 5
# Training Loss   : 0.5631
# Validation Loss : 0.5784
#
# EPOCH | 6
# Training Loss   : 0.5546
# Validation Loss : 0.5830
#
# EPOCH | 7
# Training Loss   : 0.5482
# Validation Loss : 0.5767
#
# EPOCH | 8
# Training Loss   : 0.5405
# Validation Loss : 0.5781
#
# EPOCH | 9
# Training Loss   : 0.5321
# Validation Loss : 0.5905
#
# EPOCH | 10
# Training Loss   : 0.5199
# Validation Loss : 0.5999
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.0046
#
# Test number 16 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 206289
#
# EPOCH | 0
# Training Loss   : 0.5733
# Validation Loss : 0.5686
#
# EPOCH | 1
# Training Loss   : 0.5696
# Validation Loss : 0.5787
#
# EPOCH | 2
# Training Loss   : 0.5669
# Validation Loss : 0.5753
#
# EPOCH | 3
# Training Loss   : 0.5646
# Validation Loss : 0.5868
#
# EPOCH | 4
# Training Loss   : 0.5618
# Validation Loss : 0.5668
#
# EPOCH | 5
# Training Loss   : 0.5631
# Validation Loss : 0.5784
#
# EPOCH | 6
# Training Loss   : 0.5546
# Validation Loss : 0.5830
#
# EPOCH | 7
# Training Loss   : 0.5482
# Validation Loss : 0.5767
#
# EPOCH | 8
# Training Loss   : 0.5405
# Validation Loss : 0.5781
#
# EPOCH | 9
# Training Loss   : 0.5321
# Validation Loss : 0.5905
#
# EPOCH | 10
# Training Loss   : 0.5199
# Validation Loss : 0.5999
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.0046
#
# Test number 17 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 210641
#
# EPOCH | 0
# Training Loss   : 0.5717
# Validation Loss : 0.5749
#
# EPOCH | 1
# Training Loss   : 0.5713
# Validation Loss : 0.5803
#
# EPOCH | 2
# Training Loss   : 0.5683
# Validation Loss : 0.5901
#
# EPOCH | 3
# Training Loss   : 0.5668
# Validation Loss : 0.5713
#
# EPOCH | 4
# Training Loss   : 0.5644
# Validation Loss : 0.5684
#
# EPOCH | 5
# Training Loss   : 0.5595
# Validation Loss : 0.5698
#
# EPOCH | 6
# Training Loss   : 0.5584
# Validation Loss : 0.5751
#
# EPOCH | 7
# Training Loss   : 0.5524
# Validation Loss : 0.5839
#
# EPOCH | 8
# Training Loss   : 0.5418
# Validation Loss : 0.5650
#
# EPOCH | 9
# Training Loss   : 0.5338
# Validation Loss : 0.5703
#
# EPOCH | 10
# Training Loss   : 0.5264
# Validation Loss : 0.5900
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.0033
#
# Test number 18 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 210641
#
# EPOCH | 0
# Training Loss   : 0.5717
# Validation Loss : 0.5749
#
# EPOCH | 1
# Training Loss   : 0.5713
# Validation Loss : 0.5803
#
# EPOCH | 2
# Training Loss   : 0.5683
# Validation Loss : 0.5901
#
# EPOCH | 3
# Training Loss   : 0.5668
# Validation Loss : 0.5713
#
# EPOCH | 4
# Training Loss   : 0.5644
# Validation Loss : 0.5684
#
# EPOCH | 5
# Training Loss   : 0.5595
# Validation Loss : 0.5698
#
# EPOCH | 6
# Training Loss   : 0.5584
# Validation Loss : 0.5751
#
# EPOCH | 7
# Training Loss   : 0.5524
# Validation Loss : 0.5839
#
# EPOCH | 8
# Training Loss   : 0.5418
# Validation Loss : 0.5650
#
# EPOCH | 9
# Training Loss   : 0.5338
# Validation Loss : 0.5703
#
# EPOCH | 10
# Training Loss   : 0.5264
# Validation Loss : 0.5900
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.0033
#
# Test number 19 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 210641
#
# EPOCH | 0
# Training Loss   : 0.5717
# Validation Loss : 0.5749
#
# EPOCH | 1
# Training Loss   : 0.5713
# Validation Loss : 0.5803
#
# EPOCH | 2
# Training Loss   : 0.5683
# Validation Loss : 0.5901
#
# EPOCH | 3
# Training Loss   : 0.5668
# Validation Loss : 0.5713
#
# EPOCH | 4
# Training Loss   : 0.5644
# Validation Loss : 0.5684
#
# EPOCH | 5
# Training Loss   : 0.5595
# Validation Loss : 0.5698
#
# EPOCH | 6
# Training Loss   : 0.5584
# Validation Loss : 0.5751
#
# EPOCH | 7
# Training Loss   : 0.5524
# Validation Loss : 0.5839
#
# EPOCH | 8
# Training Loss   : 0.5418
# Validation Loss : 0.5650
#
# EPOCH | 9
# Training Loss   : 0.5338
# Validation Loss : 0.5703
#
# EPOCH | 10
# Training Loss   : 0.5264
# Validation Loss : 0.5900
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.0033
#
# Test number 20 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 210641
#
# EPOCH | 0
# Training Loss   : 0.5717
# Validation Loss : 0.5749
#
# EPOCH | 1
# Training Loss   : 0.5713
# Validation Loss : 0.5803
#
# EPOCH | 2
# Training Loss   : 0.5683
# Validation Loss : 0.5901
#
# EPOCH | 3
# Training Loss   : 0.5668
# Validation Loss : 0.5713
#
# EPOCH | 4
# Training Loss   : 0.5644
# Validation Loss : 0.5684
#
# EPOCH | 5
# Training Loss   : 0.5595
# Validation Loss : 0.5698
#
# EPOCH | 6
# Training Loss   : 0.5584
# Validation Loss : 0.5751
#
# EPOCH | 7
# Training Loss   : 0.5524
# Validation Loss : 0.5839
#
# EPOCH | 8
# Training Loss   : 0.5418
# Validation Loss : 0.5650
#
# EPOCH | 9
# Training Loss   : 0.5338
# Validation Loss : 0.5703
#
# EPOCH | 10
# Training Loss   : 0.5264
# Validation Loss : 0.5900
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.0033
#
# Test number 21 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 214993
#
# EPOCH | 0
# Training Loss   : 0.5716
# Validation Loss : 0.5697
#
# EPOCH | 1
# Training Loss   : 0.5707
# Validation Loss : 0.5785
#
# EPOCH | 2
# Training Loss   : 0.5672
# Validation Loss : 0.5825
#
# EPOCH | 3
# Training Loss   : 0.5655
# Validation Loss : 0.5690
#
# EPOCH | 4
# Training Loss   : 0.5640
# Validation Loss : 0.5717
#
# EPOCH | 5
# Training Loss   : 0.5597
# Validation Loss : 0.5755
#
# EPOCH | 6
# Training Loss   : 0.5578
# Validation Loss : 0.5810
#
# EPOCH | 7
# Training Loss   : 0.5520
# Validation Loss : 0.5861
#
# EPOCH | 8
# Training Loss   : 0.5432
# Validation Loss : 0.5628
#
# EPOCH | 9
# Training Loss   : 0.5345
# Validation Loss : 0.5777
#
# EPOCH | 10
# Training Loss   : 0.5188
# Validation Loss : 0.5714
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.0019
#
# Test number 22 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 214993
#
# EPOCH | 0
# Training Loss   : 0.5716
# Validation Loss : 0.5697
#
# EPOCH | 1
# Training Loss   : 0.5707
# Validation Loss : 0.5785
#
# EPOCH | 2
# Training Loss   : 0.5672
# Validation Loss : 0.5825
#
# EPOCH | 3
# Training Loss   : 0.5655
# Validation Loss : 0.5690
#
# EPOCH | 4
# Training Loss   : 0.5640
# Validation Loss : 0.5717
#
# EPOCH | 5
# Training Loss   : 0.5597
# Validation Loss : 0.5755
#
# EPOCH | 6
# Training Loss   : 0.5578
# Validation Loss : 0.5810
#
# EPOCH | 7
# Training Loss   : 0.5520
# Validation Loss : 0.5861
#
# EPOCH | 8
# Training Loss   : 0.5432
# Validation Loss : 0.5628
#
# EPOCH | 9
# Training Loss   : 0.5345
# Validation Loss : 0.5777
#
# EPOCH | 10
# Training Loss   : 0.5188
# Validation Loss : 0.5714
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.0019
#
# Test number 23 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 214993
#
# EPOCH | 0
# Training Loss   : 0.5716
# Validation Loss : 0.5697
#
# EPOCH | 1
# Training Loss   : 0.5707
# Validation Loss : 0.5785
#
# EPOCH | 2
# Training Loss   : 0.5672
# Validation Loss : 0.5825
#
# EPOCH | 3
# Training Loss   : 0.5655
# Validation Loss : 0.5690
#
# EPOCH | 4
# Training Loss   : 0.5640
# Validation Loss : 0.5717
#
# EPOCH | 5
# Training Loss   : 0.5597
# Validation Loss : 0.5755
#
# EPOCH | 6
# Training Loss   : 0.5578
# Validation Loss : 0.5810
#
# EPOCH | 7
# Training Loss   : 0.5520
# Validation Loss : 0.5861
#
# EPOCH | 8
# Training Loss   : 0.5432
# Validation Loss : 0.5628
#
# EPOCH | 9
# Training Loss   : 0.5345
# Validation Loss : 0.5777
#
# EPOCH | 10
# Training Loss   : 0.5188
# Validation Loss : 0.5714
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.0019
#
# Test number 24 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 214993
#
# EPOCH | 0
# Training Loss   : 0.5716
# Validation Loss : 0.5697
#
# EPOCH | 1
# Training Loss   : 0.5707
# Validation Loss : 0.5785
#
# EPOCH | 2
# Training Loss   : 0.5672
# Validation Loss : 0.5825
#
# EPOCH | 3
# Training Loss   : 0.5655
# Validation Loss : 0.5690
#
# EPOCH | 4
# Training Loss   : 0.5640
# Validation Loss : 0.5717
#
# EPOCH | 5
# Training Loss   : 0.5597
# Validation Loss : 0.5755
#
# EPOCH | 6
# Training Loss   : 0.5578
# Validation Loss : 0.5810
#
# EPOCH | 7
# Training Loss   : 0.5520
# Validation Loss : 0.5861
#
# EPOCH | 8
# Training Loss   : 0.5432
# Validation Loss : 0.5628
#
# EPOCH | 9
# Training Loss   : 0.5345
# Validation Loss : 0.5777
#
# EPOCH | 10
# Training Loss   : 0.5188
# Validation Loss : 0.5714
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.0019
#
# Test number 25 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 414625
#
# EPOCH | 0
# Training Loss   : 0.5783
# Validation Loss : 0.5964
#
# EPOCH | 1
# Training Loss   : 0.5724
# Validation Loss : 0.5739
#
# EPOCH | 2
# Training Loss   : 0.5729
# Validation Loss : 0.5843
#
# EPOCH | 3
# Training Loss   : 0.5681
# Validation Loss : 0.5729
#
# EPOCH | 4
# Training Loss   : 0.5658
# Validation Loss : 0.5847
#
# EPOCH | 5
# Training Loss   : 0.5647
# Validation Loss : 0.5728
#
# EPOCH | 6
# Training Loss   : 0.5626
# Validation Loss : 0.5833
#
# EPOCH | 7
# Training Loss   : 0.5552
# Validation Loss : 0.5649
#
# EPOCH | 8
# Training Loss   : 0.5459
# Validation Loss : 0.5894
#
# EPOCH | 9
# Training Loss   : 0.5404
# Validation Loss : 0.5664
#
# EPOCH | 10
# Training Loss   : 0.5280
# Validation Loss : 0.5891
#
# EPOCH | 11
# Training Loss   : 0.5102
# Validation Loss : 0.5894
#
# EPOCH | 12
# Early stopping activated, with training and validation loss difference: 0.0014
#
# Test number 26 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 414625
#
# EPOCH | 0
# Training Loss   : 0.5783
# Validation Loss : 0.5964
#
# EPOCH | 1
# Training Loss   : 0.5724
# Validation Loss : 0.5739
#
# EPOCH | 2
# Training Loss   : 0.5729
# Validation Loss : 0.5843
#
# EPOCH | 3
# Training Loss   : 0.5681
# Validation Loss : 0.5729
#
# EPOCH | 4
# Training Loss   : 0.5658
# Validation Loss : 0.5847
#
# EPOCH | 5
# Training Loss   : 0.5647
# Validation Loss : 0.5728
#
# EPOCH | 6
# Training Loss   : 0.5626
# Validation Loss : 0.5833
#
# EPOCH | 7
# Training Loss   : 0.5552
# Validation Loss : 0.5649
#
# EPOCH | 8
# Training Loss   : 0.5459
# Validation Loss : 0.5894
#
# EPOCH | 9
# Training Loss   : 0.5404
# Validation Loss : 0.5664
#
# EPOCH | 10
# Training Loss   : 0.5280
# Validation Loss : 0.5891
#
# EPOCH | 11
# Training Loss   : 0.5102
# Validation Loss : 0.5894
#
# EPOCH | 12
# Early stopping activated, with training and validation loss difference: 0.0014
#
# Test number 27 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 414625
#
# EPOCH | 0
# Training Loss   : 0.5783
# Validation Loss : 0.5964
#
# EPOCH | 1
# Training Loss   : 0.5724
# Validation Loss : 0.5739
#
# EPOCH | 2
# Training Loss   : 0.5729
# Validation Loss : 0.5843
#
# EPOCH | 3
# Training Loss   : 0.5681
# Validation Loss : 0.5729
#
# EPOCH | 4
# Training Loss   : 0.5658
# Validation Loss : 0.5847
#
# EPOCH | 5
# Training Loss   : 0.5647
# Validation Loss : 0.5728
#
# EPOCH | 6
# Training Loss   : 0.5626
# Validation Loss : 0.5833
#
# EPOCH | 7
# Training Loss   : 0.5552
# Validation Loss : 0.5649
#
# EPOCH | 8
# Training Loss   : 0.5459
# Validation Loss : 0.5894
#
# EPOCH | 9
# Training Loss   : 0.5404
# Validation Loss : 0.5664
#
# EPOCH | 10
# Training Loss   : 0.5280
# Validation Loss : 0.5891
#
# EPOCH | 11
# Training Loss   : 0.5102
# Validation Loss : 0.5894
#
# EPOCH | 12
# Early stopping activated, with training and validation loss difference: 0.0014
#
# Test number 28 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 414625
#
# EPOCH | 0
# Training Loss   : 0.5783
# Validation Loss : 0.5964
#
# EPOCH | 1
# Training Loss   : 0.5724
# Validation Loss : 0.5739
#
# EPOCH | 2
# Training Loss   : 0.5729
# Validation Loss : 0.5843
#
# EPOCH | 3
# Training Loss   : 0.5681
# Validation Loss : 0.5729
#
# EPOCH | 4
# Training Loss   : 0.5658
# Validation Loss : 0.5847
#
# EPOCH | 5
# Training Loss   : 0.5647
# Validation Loss : 0.5728
#
# EPOCH | 6
# Training Loss   : 0.5626
# Validation Loss : 0.5833
#
# EPOCH | 7
# Training Loss   : 0.5552
# Validation Loss : 0.5649
#
# EPOCH | 8
# Training Loss   : 0.5459
# Validation Loss : 0.5894
#
# EPOCH | 9
# Training Loss   : 0.5404
# Validation Loss : 0.5664
#
# EPOCH | 10
# Training Loss   : 0.5280
# Validation Loss : 0.5891
#
# EPOCH | 11
# Training Loss   : 0.5102
# Validation Loss : 0.5894
#
# EPOCH | 12
# Early stopping activated, with training and validation loss difference: 0.0014
#
# Test number 29 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 431521
#
# EPOCH | 0
# Training Loss   : 0.5783
# Validation Loss : 0.5931
#
# EPOCH | 1
# Training Loss   : 0.5736
# Validation Loss : 0.5765
#
# EPOCH | 2
# Training Loss   : 0.5730
# Validation Loss : 0.5732
#
# EPOCH | 3
# Training Loss   : 0.5722
# Validation Loss : 0.5755
#
# EPOCH | 4
# Training Loss   : 0.5664
# Validation Loss : 0.5782
#
# EPOCH | 5
# Training Loss   : 0.5624
# Validation Loss : 0.5698
#
# EPOCH | 6
# Training Loss   : 0.5587
# Validation Loss : 0.5784
#
# EPOCH | 7
# Training Loss   : 0.5547
# Validation Loss : 0.5616
#
# EPOCH | 8
# Training Loss   : 0.5507
# Validation Loss : 0.5707
#
# EPOCH | 9
# Training Loss   : 0.5421
# Validation Loss : 0.5759
#
# EPOCH | 10
# Training Loss   : 0.5302
# Validation Loss : 0.5997
#
# EPOCH | 11
# Training Loss   : 0.5124
# Validation Loss : 0.6029
#
# EPOCH | 12
# Training Loss   : 0.4907
# Validation Loss : 0.5991
#
# EPOCH | 13
# Early stopping activated, with training and validation loss difference: 0.0002
#
# Test number 30 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 431521
#
# EPOCH | 0
# Training Loss   : 0.5783
# Validation Loss : 0.5931
#
# EPOCH | 1
# Training Loss   : 0.5736
# Validation Loss : 0.5765
#
# EPOCH | 2
# Training Loss   : 0.5730
# Validation Loss : 0.5732
#
# EPOCH | 3
# Training Loss   : 0.5722
# Validation Loss : 0.5755
#
# EPOCH | 4
# Training Loss   : 0.5664
# Validation Loss : 0.5782
#
# EPOCH | 5
# Training Loss   : 0.5624
# Validation Loss : 0.5698
#
# EPOCH | 6
# Training Loss   : 0.5587
# Validation Loss : 0.5784
#
# EPOCH | 7
# Training Loss   : 0.5547
# Validation Loss : 0.5616
#
# EPOCH | 8
# Training Loss   : 0.5507
# Validation Loss : 0.5707
#
# EPOCH | 9
# Training Loss   : 0.5421
# Validation Loss : 0.5759
#
# EPOCH | 10
# Training Loss   : 0.5302
# Validation Loss : 0.5997
#
# EPOCH | 11
# Training Loss   : 0.5124
# Validation Loss : 0.6029
#
# EPOCH | 12
# Training Loss   : 0.4907
# Validation Loss : 0.5991
#
# EPOCH | 13
# Early stopping activated, with training and validation loss difference: 0.0002
#
# Test number 31 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 431521
#
# EPOCH | 0
# Training Loss   : 0.5783
# Validation Loss : 0.5931
#
# EPOCH | 1
# Training Loss   : 0.5736
# Validation Loss : 0.5765
#
# EPOCH | 2
# Training Loss   : 0.5730
# Validation Loss : 0.5732
#
# EPOCH | 3
# Training Loss   : 0.5722
# Validation Loss : 0.5755
#
# EPOCH | 4
# Training Loss   : 0.5664
# Validation Loss : 0.5782
#
# EPOCH | 5
# Training Loss   : 0.5624
# Validation Loss : 0.5698
#
# EPOCH | 6
# Training Loss   : 0.5587
# Validation Loss : 0.5784
#
# EPOCH | 7
# Training Loss   : 0.5547
# Validation Loss : 0.5616
#
# EPOCH | 8
# Training Loss   : 0.5507
# Validation Loss : 0.5707
#
# EPOCH | 9
# Training Loss   : 0.5421
# Validation Loss : 0.5759
#
# EPOCH | 10
# Training Loss   : 0.5302
# Validation Loss : 0.5997
#
# EPOCH | 11
# Training Loss   : 0.5124
# Validation Loss : 0.6029
#
# EPOCH | 12
# Training Loss   : 0.4907
# Validation Loss : 0.5991
#
# EPOCH | 13
# Early stopping activated, with training and validation loss difference: 0.0002
#
# Test number 32 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 431521
#
# EPOCH | 0
# Training Loss   : 0.5783
# Validation Loss : 0.5931
#
# EPOCH | 1
# Training Loss   : 0.5736
# Validation Loss : 0.5765
#
# EPOCH | 2
# Training Loss   : 0.5730
# Validation Loss : 0.5732
#
# EPOCH | 3
# Training Loss   : 0.5722
# Validation Loss : 0.5755
#
# EPOCH | 4
# Training Loss   : 0.5664
# Validation Loss : 0.5782
#
# EPOCH | 5
# Training Loss   : 0.5624
# Validation Loss : 0.5698
#
# EPOCH | 6
# Training Loss   : 0.5587
# Validation Loss : 0.5784
#
# EPOCH | 7
# Training Loss   : 0.5547
# Validation Loss : 0.5616
#
# EPOCH | 8
# Training Loss   : 0.5507
# Validation Loss : 0.5707
#
# EPOCH | 9
# Training Loss   : 0.5421
# Validation Loss : 0.5759
#
# EPOCH | 10
# Training Loss   : 0.5302
# Validation Loss : 0.5997
#
# EPOCH | 11
# Training Loss   : 0.5124
# Validation Loss : 0.6029
#
# EPOCH | 12
# Training Loss   : 0.4907
# Validation Loss : 0.5991
#
# EPOCH | 13
# Early stopping activated, with training and validation loss difference: 0.0002
#
# Test number 33 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 448417
#
# EPOCH | 0
# Training Loss   : 0.5763
# Validation Loss : 0.5936
#
# EPOCH | 1
# Training Loss   : 0.5748
# Validation Loss : 0.5722
#
# EPOCH | 2
# Training Loss   : 0.5746
# Validation Loss : 0.5796
#
# EPOCH | 3
# Training Loss   : 0.5701
# Validation Loss : 0.5880
#
# EPOCH | 4
# Training Loss   : 0.5676
# Validation Loss : 0.5800
#
# EPOCH | 5
# Training Loss   : 0.5658
# Validation Loss : 0.5757
#
# EPOCH | 6
# Training Loss   : 0.5614
# Validation Loss : 0.5771
#
# EPOCH | 7
# Training Loss   : 0.5577
# Validation Loss : 0.5865
#
# EPOCH | 8
# Training Loss   : 0.5505
# Validation Loss : 0.5602
#
# EPOCH | 9
# Training Loss   : 0.5421
# Validation Loss : 0.5737
#
# EPOCH | 10
# Training Loss   : 0.5303
# Validation Loss : 0.5697
#
# EPOCH | 11
# Training Loss   : 0.5156
# Validation Loss : 0.5990
#
# EPOCH | 12
# Early stopping activated, with training and validation loss difference: 0.0026
#
# Test number 34 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 448417
#
# EPOCH | 0
# Training Loss   : 0.5763
# Validation Loss : 0.5936
#
# EPOCH | 1
# Training Loss   : 0.5748
# Validation Loss : 0.5722
#
# EPOCH | 2
# Training Loss   : 0.5746
# Validation Loss : 0.5796
#
# EPOCH | 3
# Training Loss   : 0.5701
# Validation Loss : 0.5880
#
# EPOCH | 4
# Training Loss   : 0.5676
# Validation Loss : 0.5800
#
# EPOCH | 5
# Training Loss   : 0.5658
# Validation Loss : 0.5757
#
# EPOCH | 6
# Training Loss   : 0.5614
# Validation Loss : 0.5771
#
# EPOCH | 7
# Training Loss   : 0.5577
# Validation Loss : 0.5865
#
# EPOCH | 8
# Training Loss   : 0.5505
# Validation Loss : 0.5602
#
# EPOCH | 9
# Training Loss   : 0.5421
# Validation Loss : 0.5737
#
# EPOCH | 10
# Training Loss   : 0.5303
# Validation Loss : 0.5697
#
# EPOCH | 11
# Training Loss   : 0.5156
# Validation Loss : 0.5990
#
# EPOCH | 12
# Early stopping activated, with training and validation loss difference: 0.0026
#
# Test number 35 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 448417
#
# EPOCH | 0
# Training Loss   : 0.5763
# Validation Loss : 0.5936
#
# EPOCH | 1
# Training Loss   : 0.5748
# Validation Loss : 0.5722
#
# EPOCH | 2
# Training Loss   : 0.5746
# Validation Loss : 0.5796
#
# EPOCH | 3
# Training Loss   : 0.5701
# Validation Loss : 0.5880
#
# EPOCH | 4
# Training Loss   : 0.5676
# Validation Loss : 0.5800
#
# EPOCH | 5
# Training Loss   : 0.5658
# Validation Loss : 0.5757
#
# EPOCH | 6
# Training Loss   : 0.5614
# Validation Loss : 0.5771
#
# EPOCH | 7
# Training Loss   : 0.5577
# Validation Loss : 0.5865
#
# EPOCH | 8
# Training Loss   : 0.5505
# Validation Loss : 0.5602
#
# EPOCH | 9
# Training Loss   : 0.5421
# Validation Loss : 0.5737
#
# EPOCH | 10
# Training Loss   : 0.5303
# Validation Loss : 0.5697
#
# EPOCH | 11
# Training Loss   : 0.5156
# Validation Loss : 0.5990
#
# EPOCH | 12
# Early stopping activated, with training and validation loss difference: 0.0026
#
# Test number 36 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 448417
#
# EPOCH | 0
# Training Loss   : 0.5763
# Validation Loss : 0.5936
#
# EPOCH | 1
# Training Loss   : 0.5748
# Validation Loss : 0.5722
#
# EPOCH | 2
# Training Loss   : 0.5746
# Validation Loss : 0.5796
#
# EPOCH | 3
# Training Loss   : 0.5701
# Validation Loss : 0.5880
#
# EPOCH | 4
# Training Loss   : 0.5676
# Validation Loss : 0.5800
#
# EPOCH | 5
# Training Loss   : 0.5658
# Validation Loss : 0.5757
#
# EPOCH | 6
# Training Loss   : 0.5614
# Validation Loss : 0.5771
#
# EPOCH | 7
# Training Loss   : 0.5577
# Validation Loss : 0.5865
#
# EPOCH | 8
# Training Loss   : 0.5505
# Validation Loss : 0.5602
#
# EPOCH | 9
# Training Loss   : 0.5421
# Validation Loss : 0.5737
#
# EPOCH | 10
# Training Loss   : 0.5303
# Validation Loss : 0.5697
#
# EPOCH | 11
# Training Loss   : 0.5156
# Validation Loss : 0.5990
#
# EPOCH | 12
# Early stopping activated, with training and validation loss difference: 0.0026
#
# Test number 37 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 837441
#
# EPOCH | 0
# Training Loss   : 0.5883
# Validation Loss : 0.6063
#
# EPOCH | 1
# Training Loss   : 0.5875
# Validation Loss : 0.6016
#
# EPOCH | 2
# Training Loss   : 0.5807
# Validation Loss : 0.5940
#
# EPOCH | 3
# Training Loss   : 0.5771
# Validation Loss : 0.5859
#
# EPOCH | 4
# Training Loss   : 0.5759
# Validation Loss : 0.5805
#
# EPOCH | 5
# Training Loss   : 0.5733
# Validation Loss : 0.5863
#
# EPOCH | 6
# Training Loss   : 0.5687
# Validation Loss : 0.5804
#
# EPOCH | 7
# Training Loss   : 0.5654
# Validation Loss : 0.5801
#
# EPOCH | 8
# Training Loss   : 0.5611
# Validation Loss : 0.5685
#
# EPOCH | 9
# Training Loss   : 0.5531
# Validation Loss : 0.5791
#
# EPOCH | 10
# Training Loss   : 0.5439
# Validation Loss : 0.5884
#
# EPOCH | 11
# Training Loss   : 0.5321
# Validation Loss : 0.6041
#
# EPOCH | 12
# Training Loss   : 0.5090
# Validation Loss : 0.6238
#
# EPOCH | 13
# Training Loss   : 0.4812
# Validation Loss : 0.6211
#
# EPOCH | 14
# Training Loss   : 0.4522
# Validation Loss : 0.6957
#
# EPOCH | 15
# Early stopping activated, with training and validation loss difference: 0.0046
#
# Test number 38 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 837441
#
# EPOCH | 0
# Training Loss   : 0.5883
# Validation Loss : 0.6063
#
# EPOCH | 1
# Training Loss   : 0.5875
# Validation Loss : 0.6016
#
# EPOCH | 2
# Training Loss   : 0.5807
# Validation Loss : 0.5940
#
# EPOCH | 3
# Training Loss   : 0.5771
# Validation Loss : 0.5859
#
# EPOCH | 4
# Training Loss   : 0.5759
# Validation Loss : 0.5805
#
# EPOCH | 5
# Training Loss   : 0.5733
# Validation Loss : 0.5863
#
# EPOCH | 6
# Training Loss   : 0.5687
# Validation Loss : 0.5804
#
# EPOCH | 7
# Training Loss   : 0.5654
# Validation Loss : 0.5801
#
# EPOCH | 8
# Training Loss   : 0.5611
# Validation Loss : 0.5685
#
# EPOCH | 9
# Training Loss   : 0.5531
# Validation Loss : 0.5791
#
# EPOCH | 10
# Training Loss   : 0.5439
# Validation Loss : 0.5884
#
# EPOCH | 11
# Training Loss   : 0.5321
# Validation Loss : 0.6041
#
# EPOCH | 12
# Training Loss   : 0.5090
# Validation Loss : 0.6238
#
# EPOCH | 13
# Training Loss   : 0.4812
# Validation Loss : 0.6211
#
# EPOCH | 14
# Training Loss   : 0.4522
# Validation Loss : 0.6957
#
# EPOCH | 15
# Early stopping activated, with training and validation loss difference: 0.0046
#
# Test number 39 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 837441
#
# EPOCH | 0
# Training Loss   : 0.5883
# Validation Loss : 0.6063
#
# EPOCH | 1
# Training Loss   : 0.5875
# Validation Loss : 0.6016
#
# EPOCH | 2
# Training Loss   : 0.5807
# Validation Loss : 0.5940
#
# EPOCH | 3
# Training Loss   : 0.5771
# Validation Loss : 0.5859
#
# EPOCH | 4
# Training Loss   : 0.5759
# Validation Loss : 0.5805
#
# EPOCH | 5
# Training Loss   : 0.5733
# Validation Loss : 0.5863
#
# EPOCH | 6
# Training Loss   : 0.5687
# Validation Loss : 0.5804
#
# EPOCH | 7
# Training Loss   : 0.5654
# Validation Loss : 0.5801
#
# EPOCH | 8
# Training Loss   : 0.5611
# Validation Loss : 0.5685
#
# EPOCH | 9
# Training Loss   : 0.5531
# Validation Loss : 0.5791
#
# EPOCH | 10
# Training Loss   : 0.5439
# Validation Loss : 0.5884
#
# EPOCH | 11
# Training Loss   : 0.5321
# Validation Loss : 0.6041
#
# EPOCH | 12
# Training Loss   : 0.5090
# Validation Loss : 0.6238
#
# EPOCH | 13
# Training Loss   : 0.4812
# Validation Loss : 0.6211
#
# EPOCH | 14
# Training Loss   : 0.4522
# Validation Loss : 0.6957
#
# EPOCH | 15
# Early stopping activated, with training and validation loss difference: 0.0046
#
# Test number 40 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 837441
#
# EPOCH | 0
# Training Loss   : 0.5883
# Validation Loss : 0.6063
#
# EPOCH | 1
# Training Loss   : 0.5875
# Validation Loss : 0.6016
#
# EPOCH | 2
# Training Loss   : 0.5807
# Validation Loss : 0.5940
#
# EPOCH | 3
# Training Loss   : 0.5771
# Validation Loss : 0.5859
#
# EPOCH | 4
# Training Loss   : 0.5759
# Validation Loss : 0.5805
#
# EPOCH | 5
# Training Loss   : 0.5733
# Validation Loss : 0.5863
#
# EPOCH | 6
# Training Loss   : 0.5687
# Validation Loss : 0.5804
#
# EPOCH | 7
# Training Loss   : 0.5654
# Validation Loss : 0.5801
#
# EPOCH | 8
# Training Loss   : 0.5611
# Validation Loss : 0.5685
#
# EPOCH | 9
# Training Loss   : 0.5531
# Validation Loss : 0.5791
#
# EPOCH | 10
# Training Loss   : 0.5439
# Validation Loss : 0.5884
#
# EPOCH | 11
# Training Loss   : 0.5321
# Validation Loss : 0.6041
#
# EPOCH | 12
# Training Loss   : 0.5090
# Validation Loss : 0.6238
#
# EPOCH | 13
# Training Loss   : 0.4812
# Validation Loss : 0.6211
#
# EPOCH | 14
# Training Loss   : 0.4522
# Validation Loss : 0.6957
#
# EPOCH | 15
# Early stopping activated, with training and validation loss difference: 0.0046
#
# Test number 41 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 904001
#
# EPOCH | 0
# Training Loss   : 0.5929
# Validation Loss : 0.6009
#
# EPOCH | 1
# Training Loss   : 0.5857
# Validation Loss : 0.5984
#
# EPOCH | 2
# Training Loss   : 0.5860
# Validation Loss : 0.5932
#
# EPOCH | 3
# Training Loss   : 0.5786
# Validation Loss : 0.5740
#
# EPOCH | 4
# Training Loss   : 0.5748
# Validation Loss : 0.5892
#
# EPOCH | 5
# Training Loss   : 0.5726
# Validation Loss : 0.5955
#
# EPOCH | 6
# Training Loss   : 0.5687
# Validation Loss : 0.5808
#
# EPOCH | 7
# Training Loss   : 0.5649
# Validation Loss : 0.5874
#
# EPOCH | 8
# Training Loss   : 0.5578
# Validation Loss : 0.5900
#
# EPOCH | 9
# Training Loss   : 0.5529
# Validation Loss : 0.5849
#
# EPOCH | 10
# Training Loss   : 0.5391
# Validation Loss : 0.5811
#
# EPOCH | 11
# Training Loss   : 0.5253
# Validation Loss : 0.5852
#
# EPOCH | 12
# Training Loss   : 0.5020
# Validation Loss : 0.6183
#
# EPOCH | 13
# Training Loss   : 0.4753
# Validation Loss : 0.6091
#
# EPOCH | 14
# Early stopping activated, with training and validation loss difference: 0.0046
#
# Test number 42 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 904001
#
# EPOCH | 0
# Training Loss   : 0.5929
# Validation Loss : 0.6009
#
# EPOCH | 1
# Training Loss   : 0.5857
# Validation Loss : 0.5984
#
# EPOCH | 2
# Training Loss   : 0.5860
# Validation Loss : 0.5932
#
# EPOCH | 3
# Training Loss   : 0.5786
# Validation Loss : 0.5740
#
# EPOCH | 4
# Training Loss   : 0.5748
# Validation Loss : 0.5892
#
# EPOCH | 5
# Training Loss   : 0.5726
# Validation Loss : 0.5955
#
# EPOCH | 6
# Training Loss   : 0.5687
# Validation Loss : 0.5808
#
# EPOCH | 7
# Training Loss   : 0.5649
# Validation Loss : 0.5874
#
# EPOCH | 8
# Training Loss   : 0.5578
# Validation Loss : 0.5900
#
# EPOCH | 9
# Training Loss   : 0.5529
# Validation Loss : 0.5849
#
# EPOCH | 10
# Training Loss   : 0.5391
# Validation Loss : 0.5811
#
# EPOCH | 11
# Training Loss   : 0.5253
# Validation Loss : 0.5852
#
# EPOCH | 12
# Training Loss   : 0.5020
# Validation Loss : 0.6183
#
# EPOCH | 13
# Training Loss   : 0.4753
# Validation Loss : 0.6091
#
# EPOCH | 14
# Early stopping activated, with training and validation loss difference: 0.0046
#
# Test number 43 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 904001
#
# EPOCH | 0
# Training Loss   : 0.5929
# Validation Loss : 0.6009
#
# EPOCH | 1
# Training Loss   : 0.5857
# Validation Loss : 0.5984
#
# EPOCH | 2
# Training Loss   : 0.5860
# Validation Loss : 0.5932
#
# EPOCH | 3
# Training Loss   : 0.5786
# Validation Loss : 0.5740
#
# EPOCH | 4
# Training Loss   : 0.5748
# Validation Loss : 0.5892
#
# EPOCH | 5
# Training Loss   : 0.5726
# Validation Loss : 0.5955
#
# EPOCH | 6
# Training Loss   : 0.5687
# Validation Loss : 0.5808
#
# EPOCH | 7
# Training Loss   : 0.5649
# Validation Loss : 0.5874
#
# EPOCH | 8
# Training Loss   : 0.5578
# Validation Loss : 0.5900
#
# EPOCH | 9
# Training Loss   : 0.5529
# Validation Loss : 0.5849
#
# EPOCH | 10
# Training Loss   : 0.5391
# Validation Loss : 0.5811
#
# EPOCH | 11
# Training Loss   : 0.5253
# Validation Loss : 0.5852
#
# EPOCH | 12
# Training Loss   : 0.5020
# Validation Loss : 0.6183
#
# EPOCH | 13
# Training Loss   : 0.4753
# Validation Loss : 0.6091
#
# EPOCH | 14
# Early stopping activated, with training and validation loss difference: 0.0046
#
# Test number 44 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 904001
#
# EPOCH | 0
# Training Loss   : 0.5929
# Validation Loss : 0.6009
#
# EPOCH | 1
# Training Loss   : 0.5857
# Validation Loss : 0.5984
#
# EPOCH | 2
# Training Loss   : 0.5860
# Validation Loss : 0.5932
#
# EPOCH | 3
# Training Loss   : 0.5786
# Validation Loss : 0.5740
#
# EPOCH | 4
# Training Loss   : 0.5748
# Validation Loss : 0.5892
#
# EPOCH | 5
# Training Loss   : 0.5726
# Validation Loss : 0.5955
#
# EPOCH | 6
# Training Loss   : 0.5687
# Validation Loss : 0.5808
#
# EPOCH | 7
# Training Loss   : 0.5649
# Validation Loss : 0.5874
#
# EPOCH | 8
# Training Loss   : 0.5578
# Validation Loss : 0.5900
#
# EPOCH | 9
# Training Loss   : 0.5529
# Validation Loss : 0.5849
#
# EPOCH | 10
# Training Loss   : 0.5391
# Validation Loss : 0.5811
#
# EPOCH | 11
# Training Loss   : 0.5253
# Validation Loss : 0.5852
#
# EPOCH | 12
# Training Loss   : 0.5020
# Validation Loss : 0.6183
#
# EPOCH | 13
# Training Loss   : 0.4753
# Validation Loss : 0.6091
#
# EPOCH | 14
# Early stopping activated, with training and validation loss difference: 0.0046
#
# Test number 45 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 970561
#
# EPOCH | 0
# Training Loss   : 0.5931
# Validation Loss : 0.5884
#
# EPOCH | 1
# Training Loss   : 0.5852
# Validation Loss : 0.5998
#
# EPOCH | 2
# Training Loss   : 0.5832
# Validation Loss : 0.5852
#
# EPOCH | 3
# Training Loss   : 0.5789
# Validation Loss : 0.5966
#
# EPOCH | 4
# Training Loss   : 0.5751
# Validation Loss : 0.6046
#
# EPOCH | 5
# Training Loss   : 0.5731
# Validation Loss : 0.5868
#
# EPOCH | 6
# Training Loss   : 0.5682
# Validation Loss : 0.5768
#
# EPOCH | 7
# Training Loss   : 0.5615
# Validation Loss : 0.6138
#
# EPOCH | 8
# Training Loss   : 0.5568
# Validation Loss : 0.5739
#
# EPOCH | 9
# Training Loss   : 0.5466
# Validation Loss : 0.6015
#
# EPOCH | 10
# Training Loss   : 0.5383
# Validation Loss : 0.5943
#
# EPOCH | 11
# Training Loss   : 0.5169
# Validation Loss : 0.5971
#
# EPOCH | 12
# Training Loss   : 0.5008
# Validation Loss : 0.6016
#
# EPOCH | 13
# Early stopping activated, with training and validation loss difference: 0.0021
#
# Test number 46 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 970561
#
# EPOCH | 0
# Training Loss   : 0.5931
# Validation Loss : 0.5884
#
# EPOCH | 1
# Training Loss   : 0.5852
# Validation Loss : 0.5998
#
# EPOCH | 2
# Training Loss   : 0.5832
# Validation Loss : 0.5852
#
# EPOCH | 3
# Training Loss   : 0.5789
# Validation Loss : 0.5966
#
# EPOCH | 4
# Training Loss   : 0.5751
# Validation Loss : 0.6046
#
# EPOCH | 5
# Training Loss   : 0.5731
# Validation Loss : 0.5868
#
# EPOCH | 6
# Training Loss   : 0.5682
# Validation Loss : 0.5768
#
# EPOCH | 7
# Training Loss   : 0.5615
# Validation Loss : 0.6138
#
# EPOCH | 8
# Training Loss   : 0.5568
# Validation Loss : 0.5739
#
# EPOCH | 9
# Training Loss   : 0.5466
# Validation Loss : 0.6015
#
# EPOCH | 10
# Training Loss   : 0.5383
# Validation Loss : 0.5943
#
# EPOCH | 11
# Training Loss   : 0.5169
# Validation Loss : 0.5971
#
# EPOCH | 12
# Training Loss   : 0.5008
# Validation Loss : 0.6016
#
# EPOCH | 13
# Early stopping activated, with training and validation loss difference: 0.0021
#
# Test number 47 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 970561
#
# ...
# Training Loss   : 0.2528
# Validation Loss : 1.0179
#
# EPOCH | 8
# Training Loss   : 0.1933
# Validation Loss : 1.1975
#
# EPOCH | 9
# Training Loss   : 0.1978
# Validation Loss : 1.1700
#
# EPOCH | 10
# Training Loss   : 0.1343
# Validation Loss : 1.3567
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.0339
#
# Test number 69 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 104041
#
# EPOCH | 0
# Training Loss   : 0.5623
# Validation Loss : 0.5761
#
# EPOCH | 1
# Training Loss   : 0.5593
# Validation Loss : 0.5812
#
# EPOCH | 2
# Training Loss   : 0.5555
# Validation Loss : 0.5717
#
# EPOCH | 3
# Training Loss   : 0.5500
# Validation Loss : 0.5720
#
# EPOCH | 4
# Training Loss   : 0.5440
# Validation Loss : 0.5742
#
# EPOCH | 5
# Training Loss   : 0.5342
# Validation Loss : 0.5725
#
# EPOCH | 6
# Training Loss   : 0.5268
# Validation Loss : 0.5873
#
# EPOCH | 7
# Training Loss   : 0.5115
# Validation Loss : 0.5602
#
# EPOCH | 8
# Training Loss   : 0.4976
# Validation Loss : 0.6037
#
# EPOCH | 9
# Training Loss   : 0.4780
# Validation Loss : 0.5957
#
# EPOCH | 10
# Training Loss   : 0.4534
# Validation Loss : 0.6457
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.0138
#
# Test number 70 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 104041
#
# EPOCH | 0
# Training Loss   : 0.5658
# Validation Loss : 0.5964
#
# EPOCH | 1
# Training Loss   : 0.5338
# Validation Loss : 0.6214
#
# EPOCH | 2
# Training Loss   : 0.5048
# Validation Loss : 0.6033
#
# EPOCH | 3
# Training Loss   : 0.4769
# Validation Loss : 0.6228
#
# EPOCH | 4
# Training Loss   : 0.4432
# Validation Loss : 0.6839
#
# EPOCH | 5
# Training Loss   : 0.3872
# Validation Loss : 0.7975
#
# EPOCH | 6
# Training Loss   : 0.3562
# Validation Loss : 0.8280
#
# EPOCH | 7
# Training Loss   : 0.3247
# Validation Loss : 0.8948
#
# EPOCH | 8
# Training Loss   : 0.2857
# Validation Loss : 0.9349
#
# EPOCH | 9
# Training Loss   : 0.2420
# Validation Loss : 1.0263
#
# EPOCH | 10
# Training Loss   : 0.2009
# Validation Loss : 1.1531
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.0306
#
# Test number 71 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 104041
#
# EPOCH | 0
# Training Loss   : 0.5704
# Validation Loss : 0.5840
#
# EPOCH | 1
# Training Loss   : 0.5605
# Validation Loss : 0.5833
#
# EPOCH | 2
# Training Loss   : 0.5540
# Validation Loss : 0.5962
#
# EPOCH | 3
# Training Loss   : 0.5454
# Validation Loss : 0.5851
#
# EPOCH | 4
# Training Loss   : 0.5398
# Validation Loss : 0.5847
#
# EPOCH | 5
# Training Loss   : 0.5191
# Validation Loss : 0.6244
#
# EPOCH | 6
# Training Loss   : 0.4985
# Validation Loss : 0.6361
#
# EPOCH | 7
# Training Loss   : 0.4821
# Validation Loss : 0.6093
#
# EPOCH | 8
# Training Loss   : 0.4556
# Validation Loss : 0.6638
#
# EPOCH | 9
# Training Loss   : 0.4227
# Validation Loss : 0.7518
#
# EPOCH | 10
# Training Loss   : 0.3800
# Validation Loss : 0.7600
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.0136
#
# Test number 72 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 104041
#
# EPOCH | 0
# Training Loss   : 0.5744
# Validation Loss : 0.5776
#
# EPOCH | 1
# Training Loss   : 0.5726
# Validation Loss : 0.5746
#
# EPOCH | 2
# Training Loss   : 0.5717
# Validation Loss : 0.5736
#
# EPOCH | 3
# Training Loss   : 0.5682
# Validation Loss : 0.5704
#
# EPOCH | 4
# Training Loss   : 0.5683
# Validation Loss : 0.5849
#
# EPOCH | 5
# Training Loss   : 0.5659
# Validation Loss : 0.5784
#
# EPOCH | 6
# Training Loss   : 0.5640
# Validation Loss : 0.5695
#
# EPOCH | 7
# Training Loss   : 0.5613
# Validation Loss : 0.5688
#
# EPOCH | 8
# Training Loss   : 0.5600
# Validation Loss : 0.5733
#
# EPOCH | 9
# Training Loss   : 0.5532
# Validation Loss : 0.5789
#
# EPOCH | 10
# Training Loss   : 0.5451
# Validation Loss : 0.5756
#
# EPOCH | 11
# Training Loss   : 0.5401
# Validation Loss : 0.5759
#
# EPOCH | 12
# Training Loss   : 0.5335
# Validation Loss : 0.5888
#
# EPOCH | 13
# Early stopping activated, with training and validation loss difference: 0.0019
#
# Test number 73 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 104041
#
# EPOCH | 0
# Training Loss   : 0.5645
# Validation Loss : 0.5806
#
# EPOCH | 1
# Training Loss   : 0.5042
# Validation Loss : 0.5858
#
# EPOCH | 2
# Training Loss   : 0.4104
# Validation Loss : 0.6013
#
# EPOCH | 3
# Training Loss   : 0.3193
# Validation Loss : 0.6268
#
# EPOCH | 4
# Training Loss   : 0.2490
# Validation Loss : 0.6556
#
# EPOCH | 5
# Training Loss   : 0.1979
# Validation Loss : 0.6852
#
# EPOCH | 6
# Training Loss   : 0.1610
# Validation Loss : 0.7143
#
# EPOCH | 7
# Training Loss   : 0.1339
# Validation Loss : 0.7422
#
# EPOCH | 8
# Training Loss   : 0.1139
# Validation Loss : 0.7695
#
# EPOCH | 9
# Training Loss   : 0.0985
# Validation Loss : 0.7954
#
# EPOCH | 10
# Training Loss   : 0.0865
# Validation Loss : 0.8196
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.0161
#
# Test number 74 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 104041
#
# EPOCH | 0
# Training Loss   : 0.5648
# Validation Loss : 0.5809
#
# EPOCH | 1
# Training Loss   : 0.5045
# Validation Loss : 0.5864
#
# EPOCH | 2
# Training Loss   : 0.4041
# Validation Loss : 0.6038
#
# EPOCH | 3
# Training Loss   : 0.3059
# Validation Loss : 0.6305
#
# EPOCH | 4
# Training Loss   : 0.2315
# Validation Loss : 0.6621
#
# EPOCH | 5
# Training Loss   : 0.1791
# Validation Loss : 0.6922
#
# EPOCH | 6
# Training Loss   : 0.1421
# Validation Loss : 0.7211
#
# EPOCH | 7
# Training Loss   : 0.1157
# Validation Loss : 0.7514
#
# EPOCH | 8
# Training Loss   : 0.0965
# Validation Loss : 0.7817
#
# EPOCH | 9
# Training Loss   : 0.0820
# Validation Loss : 0.8108
#
# EPOCH | 10
# Training Loss   : 0.0707
# Validation Loss : 0.8357
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.0161
#
# Test number 75 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 104041
#
# EPOCH | 0
# Training Loss   : 0.5681
# Validation Loss : 0.5799
#
# EPOCH | 1
# Training Loss   : 0.5266
# Validation Loss : 0.5825
#
# EPOCH | 2
# Training Loss   : 0.4293
# Validation Loss : 0.5937
#
# EPOCH | 3
# Training Loss   : 0.2966
# Validation Loss : 0.6280
#
# EPOCH | 4
# Training Loss   : 0.1982
# Validation Loss : 0.6810
#
# EPOCH | 5
# Training Loss   : 0.1393
# Validation Loss : 0.7432
#
# EPOCH | 6
# Training Loss   : 0.1035
# Validation Loss : 0.8032
#
# EPOCH | 7
# Training Loss   : 0.0812
# Validation Loss : 0.8552
#
# EPOCH | 8
# Training Loss   : 0.0666
# Validation Loss : 0.9020
#
# EPOCH | 9
# Training Loss   : 0.0566
# Validation Loss : 0.9435
#
# EPOCH | 10
# Training Loss   : 0.0496
# Validation Loss : 0.9789
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.0118
#
# Test number 76 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 104041
#
# EPOCH | 0
# Training Loss   : 0.4530
# Validation Loss : 0.6705
#
# EPOCH | 1
# Training Loss   : 0.1402
# Validation Loss : 0.9134
#
# EPOCH | 2
# Training Loss   : 0.0387
# Validation Loss : 1.1036
#
# EPOCH | 3
# Training Loss   : 0.0176
# Validation Loss : 1.2183
#
# EPOCH | 4
# Training Loss   : 0.0109
# Validation Loss : 1.3049
#
# EPOCH | 5
# Training Loss   : 0.0077
# Validation Loss : 1.3768
#
# EPOCH | 6
# Training Loss   : 0.0063
# Validation Loss : 1.4284
#
# EPOCH | 7
# Training Loss   : 0.0053
# Validation Loss : 1.4791
#
# EPOCH | 8
# Training Loss   : 0.0045
# Validation Loss : 1.5236
#
# EPOCH | 9
# Training Loss   : 0.0038
# Validation Loss : 1.5597
#
# EPOCH | 10
# Training Loss   : 0.0033
# Validation Loss : 1.5933
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.2176
#
# Test number 77 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 104041
#
# EPOCH | 0
# Training Loss   : 0.4533
# Validation Loss : 0.7294
#
# EPOCH | 1
# Training Loss   : 0.1453
# Validation Loss : 1.0290
#
# EPOCH | 2
# Training Loss   : 0.0393
# Validation Loss : 1.1646
#
# EPOCH | 3
# Training Loss   : 0.0259
# Validation Loss : 1.3086
#
# EPOCH | 4
# Training Loss   : 0.0593
# Validation Loss : 1.2796
#
# EPOCH | 5
# Training Loss   : 0.0246
# Validation Loss : 1.4109
#
# EPOCH | 6
# Training Loss   : 0.0073
# Validation Loss : 1.4332
#
# EPOCH | 7
# Training Loss   : 0.0046
# Validation Loss : 1.4637
#
# EPOCH | 8
# Training Loss   : 0.0041
# Validation Loss : 1.4856
#
# EPOCH | 9
# Training Loss   : 0.0037
# Validation Loss : 1.5022
#
# EPOCH | 10
# Training Loss   : 0.0035
# Validation Loss : 1.5177
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.2761
#
# Test number 78 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 104041
#
# EPOCH | 0
# Training Loss   : 0.4871
# Validation Loss : 0.6663
#
# EPOCH | 1
# Training Loss   : 0.2791
# Validation Loss : 0.8950
#
# EPOCH | 2
# Training Loss   : 0.1689
# Validation Loss : 0.9795
#
# EPOCH | 3
# Training Loss   : 0.1047
# Validation Loss : 1.0407
#
# EPOCH | 4
# Training Loss   : 0.0791
# Validation Loss : 1.1239
#
# EPOCH | 5
# Training Loss   : 0.0794
# Validation Loss : 1.1803
#
# EPOCH | 6
# Training Loss   : 0.0526
# Validation Loss : 1.1617
#
# EPOCH | 7
# Training Loss   : 0.0421
# Validation Loss : 1.2144
#
# EPOCH | 8
# Training Loss   : 0.0302
# Validation Loss : 1.2770
#
# EPOCH | 9
# Training Loss   : 0.0206
# Validation Loss : 1.3021
#
# EPOCH | 10
# Training Loss   : 0.0156
# Validation Loss : 1.3066
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.1793
#
# Test number 79 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 104041
#
# EPOCH | 0
# Training Loss   : 0.5154
# Validation Loss : 0.6583
#
# EPOCH | 1
# Training Loss   : 0.3753
# Validation Loss : 0.7648
#
# EPOCH | 2
# Training Loss   : 0.2656
# Validation Loss : 0.9242
#
# EPOCH | 3
# Training Loss   : 0.2111
# Validation Loss : 1.0251
#
# EPOCH | 4
# Training Loss   : 0.1614
# Validation Loss : 1.1423
#
# EPOCH | 5
# Training Loss   : 0.1213
# Validation Loss : 1.3606
#
# EPOCH | 6
# Training Loss   : 0.0937
# Validation Loss : 1.4580
#
# EPOCH | 7
# Training Loss   : 0.0755
# Validation Loss : 1.4868
#
# EPOCH | 8
# Training Loss   : 0.0544
# Validation Loss : 1.6225
#
# EPOCH | 9
# Training Loss   : 0.0438
# Validation Loss : 1.6779
#
# EPOCH | 10
# Training Loss   : 0.0398
# Validation Loss : 1.7300
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.1430
#
# Test number 80 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 104041
#
# EPOCH | 0
# Training Loss   : 0.5147
# Validation Loss : 0.6228
#
# EPOCH | 1
# Training Loss   : 0.4202
# Validation Loss : 0.6534
#
# EPOCH | 2
# Training Loss   : 0.3537
# Validation Loss : 0.8136
#
# EPOCH | 3
# Training Loss   : 0.2955
# Validation Loss : 0.8662
#
# EPOCH | 4
# Training Loss   : 0.2593
# Validation Loss : 0.9664
#
# EPOCH | 5
# Training Loss   : 0.2087
# Validation Loss : 1.0349
#
# EPOCH | 6
# Training Loss   : 0.1766
# Validation Loss : 1.2127
#
# EPOCH | 7
# Training Loss   : 0.1424
# Validation Loss : 1.2493
#
# EPOCH | 8
# Training Loss   : 0.1215
# Validation Loss : 1.3506
#
# EPOCH | 9
# Training Loss   : 0.0892
# Validation Loss : 1.3796
#
# EPOCH | 10
# Training Loss   : 0.0428
# Validation Loss : 1.5398
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.1081
#
# Test number 81 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 104041
#
# EPOCH | 0
# Training Loss   : 0.5515
# Validation Loss : 0.5778
#
# EPOCH | 1
# Training Loss   : 0.5366
# Validation Loss : 0.5596
#
# EPOCH | 2
# Training Loss   : 0.5236
# Validation Loss : 0.5751
#
# EPOCH | 3
# Training Loss   : 0.5145
# Validation Loss : 0.5865
#
# EPOCH | 4
# Training Loss   : 0.4982
# Validation Loss : 0.5842
#
# EPOCH | 5
# Training Loss   : 0.4846
# Validation Loss : 0.6163
#
# EPOCH | 6
# Training Loss   : 0.4659
# Validation Loss : 0.6516
#
# EPOCH | 7
# Training Loss   : 0.4441
# Validation Loss : 0.6403
#
# EPOCH | 8
# Training Loss   : 0.4129
# Validation Loss : 0.7045
#
# EPOCH | 9
# Training Loss   : 0.3820
# Validation Loss : 0.6172
#
# EPOCH | 10
# Training Loss   : 0.3464
# Validation Loss : 0.7570
#
# EPOCH | 11
# Training Loss   : 0.2950
# Validation Loss : 0.7687
#
# EPOCH | 12
# Early stopping activated, with training and validation loss difference: 0.0229
#
# Test number 82 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 104041
#
# EPOCH | 0
# Training Loss   : 0.5494
# Validation Loss : 0.6230
#
# EPOCH | 1
# Training Loss   : 0.4867
# Validation Loss : 0.6334
#
# EPOCH | 2
# Training Loss   : 0.4279
# Validation Loss : 0.7584
#
# EPOCH | 3
# Training Loss   : 0.3841
# Validation Loss : 0.8422
#
# EPOCH | 4
# Training Loss   : 0.3509
# Validation Loss : 0.8757
#
# EPOCH | 5
# Training Loss   : 0.2984
# Validation Loss : 1.0412
#
# EPOCH | 6
# Training Loss   : 0.2538
# Validation Loss : 1.0502
#
# EPOCH | 7
# Training Loss   : 0.2205
# Validation Loss : 1.1965
#
# EPOCH | 8
# Training Loss   : 0.1952
# Validation Loss : 1.1952
#
# EPOCH | 9
# Training Loss   : 0.1526
# Validation Loss : 1.4399
#
# EPOCH | 10
# Training Loss   : 0.1271
# Validation Loss : 1.4700
#
# EPOCH | 11
# Early stopping activated, with training and validation loss difference: 0.0737
#
# Test number 83 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 104041
#
# EPOCH | 0
# Training Loss   : 0.5523
# Validation Loss : 0.6486
#
# EPOCH | 1
# Training Loss   : 0.5256
# Validation Loss : 0.6112
#
# EPOCH | 2
# Training Loss   : 0.5023
# Validation Loss : 0.6371
#
# EPOCH | 3
# Training Loss   : 0.4803
# Validation Loss : 0.6327
#
# EPOCH | 4
# Training Loss   : 0.4614
# Validation Loss : 0.6671
#
# EPOCH | 5
# Training Loss   : 0.4386
# Validation Loss : 0.6649
#
# EPOCH | 6
# Training Loss   : 0.4082
# Validation Loss : 0.7498
#
# EPOCH | 7
# Training Loss   : 0.3743
# Validation Loss : 0.7518
#
# EPOCH | 8
# Training Loss   : 0.3425
# Validation Loss : 0.7875
#
# EPOCH | 9
# Training Loss   : 0.2996
# Validation Loss : 0.8507
#
# EPOCH | 10
# Training Loss   : 0.2842
# Validation Loss : 0.9044
#
# EPOCH | 11
# Training Loss   : 0.2377
# Validation Loss : 1.0052
#
# EPOCH | 12
# Early stopping activated, with training and validation loss difference: 0.0857
#
# Test number 84 | Start testing new parameter-combination...
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 104041
#
# EPOCH | 0
# Training Loss   : 0.5690
# Validation Loss : 0.5778
#
# EPOCH | 1
# Training Loss   : 0.5644
# Validation Loss : 0.5701
#
# EPOCH | 2
# Training Loss   : 0.5627
# Validation Loss : 0.5748
#
# EPOCH | 3
# Training Loss   : 0.5579
# Validation Loss : 0.5744
#
# EPOCH | 4
# Training Loss   : 0.5542
# Validation Loss : 0.5828
#
# EPOCH | 5
# Training Loss   : 0.5533
# Validation Loss : 0.5615
#
# EPOCH | 6
# Training Loss   : 0.5458
# Validation Loss : 0.5752
#
# EPOCH | 7
# Training Loss   : 0.5390
# Validation Loss : 0.5699
#
# EPOCH | 8
# Training Loss   : 0.5368
# Validation Loss : 0.5712
#
# EPOCH | 9
# Training Loss   : 0.5272
# Validation Loss : 0.5767
#
# EPOCH | 10
# Training Loss   : 0.5177
# Validation Loss : 0.5934
#
# EPOCH | 11
# Training Loss   : 0.5038
# Validation Loss : 0.5912
#
# EPOCH | 12
# Early stopping activated, with training and validation loss difference: 0.0058
#
# Best hyperparameters were: {'batch_size': 16, 'learning_rate': 0.05, 'weight_decay': 0.001, 'pos_weight': 0.6962982977573628, 'model_hidden_units': 8, 'model_num_layers': 3, 'model_dropout': 0.0}

# %% [markdown]
# **Train with the best parameters**: The LSTM is trained using the selected parameters.

# %%
# Access the best parameters in order to train final model
with open('best_parameters_same_sets.txt') as f:
    data = f.read()

best_parameters_loaded = json.loads(data)

print('\nNow training with the best parameters\n')
training(params=best_parameters_loaded, make_err_logs=True)
# Out:
# Now training with the best parameters
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
# Model loading completed
#
# Number of model parameters: 104041
#
# EPOCH | 0
# Training Loss   : 0.5709
# Validation Loss : 0.5688
#
# EPOCH | 1
# Training Loss   : 0.5679
# Validation Loss : 0.5760
#
# EPOCH | 2
# Training Loss   : 0.5670
# Validation Loss : 0.5757
#
# EPOCH | 3
# Training Loss   : 0.5654
# Validation Loss : 0.5671
#
# EPOCH | 4
# Training Loss   : 0.5639
# Validation Loss : 0.5631
#
# EPOCH | 5
# Training Loss   : 0.5603
# Validation Loss : 0.5810
#
# EPOCH | 6
# Training Loss   : 0.5525
# Validation Loss : 0.5661
#
# EPOCH | 7
# Training Loss   : 0.5477
# Validation Loss : 0.5778
#
# EPOCH | 8
# Training Loss   : 0.5401
# Validation Loss : 0.5721
#
# EPOCH | 9
# Training Loss   : 0.5302
# Validation Loss : 0.5888
#
# EPOCH | 10
# Training Loss   : 0.5182
# Validation Loss : 0.6114
#
# EPOCH | 11
# Training Loss   : 0.5002
# Validation Loss : 0.6008
#
# EPOCH | 12
# Training Loss   : 0.4770
# Validation Loss : 0.6238
#
# EPOCH | 13
# Training Loss   : 0.4483
# Validation Loss : 0.6413
#
# EPOCH | 14
# Training Loss   : 0.4113
# Validation Loss : 0.6932
#
# EPOCH | 15
# Early stopping activated, with training and validation loss difference: 0.0008
#
# Training has stopped, now continuing with logging
#
# EPOCH | 16
# Training Loss   : 0.3716
# Validation Loss : 0.7138
#
# EPOCH | 17
# Training Loss   : 0.3122
# Validation Loss : 0.8056
#
# EPOCH | 18
# Training Loss   : 0.2785
# Validation Loss : 0.8071
#
# EPOCH | 19
# Training Loss   : 0.2262
# Validation Loss : 0.8416
#
# EPOCH | 20
# Training Loss   : 0.1916
# Validation Loss : 0.9937
#
# EPOCH | 21
# Training Loss   : 0.1650
# Validation Loss : 0.9431
#
# EPOCH | 22
# Training Loss   : 0.1245
# Validation Loss : 1.1085
#
# EPOCH | 23
# Training Loss   : 0.1189
# Validation Loss : 1.1100
#
# EPOCH | 24
# Training Loss   : 0.0929
# Validation Loss : 1.0901
#
# EPOCH | 25
# Training Loss   : 0.0678
# Validation Loss : 1.2403
#
# EPOCH | 26
# Training Loss   : 0.0859
# Validation Loss : 1.1560
#
# EPOCH | 27
# Training Loss   : 0.0541
# Validation Loss : 1.2428
#
# EPOCH | 28
# Training Loss   : 0.0395
# Validation Loss : 1.4067
#
# EPOCH | 29
# Training Loss   : 0.0713
# Validation Loss : 1.3938
#
# EPOCH | 30
# Training Loss   : 0.0289
# Validation Loss : 1.3973
#
# EPOCH | 31
# Training Loss   : 0.0171
# Validation Loss : 1.3571
#
# EPOCH | 32
# Training Loss   : 0.0213
# Validation Loss : 1.4820
#
# EPOCH | 33
# Training Loss   : 0.1223
# Validation Loss : 1.2426
#
# EPOCH | 34
# Training Loss   : 0.0180
# Validation Loss : 1.3411
#
# EPOCH | 35
# Training Loss   : 0.0145
# Validation Loss : 1.3762
#
# EPOCH | 36
# Training Loss   : 0.0152
# Validation Loss : 1.3994
#
# EPOCH | 37
# Training Loss   : 0.0146
# Validation Loss : 1.4286
#
# EPOCH | 38
# Training Loss   : 0.0769
# Validation Loss : 1.3225
#
# EPOCH | 39
# Training Loss   : 0.0298
# Validation Loss : 1.4235
#
# EPOCH | 40
# Training Loss   : 0.0126
# Validation Loss : 1.4511
#
# EPOCH | 41
# Training Loss   : 0.0123
# Validation Loss : 1.4660
#
# EPOCH | 42
# Training Loss   : 0.0124
# Validation Loss : 1.4808
#
# EPOCH | 43
# Training Loss   : 0.0129
# Validation Loss : 1.4881
#
# EPOCH | 44
# Training Loss   : 0.0122
# Validation Loss : 1.4931
#
# EPOCH | 45
# Training Loss   : 0.0125
# Validation Loss : 1.4781
#
# EPOCH | 46
# Training Loss   : 0.0286
# Validation Loss : 1.4599
#
# EPOCH | 47
# Training Loss   : 0.0225
# Validation Loss : 1.4390
#
# EPOCH | 48
# Training Loss   : 0.0106
# Validation Loss : 1.4372
#
# EPOCH | 49
# Training Loss   : 0.0104
# Validation Loss : 1.4314
#
# EPOCH | 50
# Training Loss   : 0.0105
# Validation Loss : 1.4272
#
# Finishing training with best training loss: 0.5639 and best validation loss: 0.5631
# 0.5631081468603584

# %% [markdown]
# The following Figure shows the ***training and validation set errors***, the epoch where the ***early stopping*** was activated, as well as the epoch of the final ***selected model***.

# %%
display(HTML('<img src="plots/train_valid_error.png?%d" height=400 width=400>' % __counter__))
# Out:
# <img src="plots/train_valid_error.png?38918339" height=400 width=400>

# %% [markdown]
# **Test the model**: Predict the satisfiability of the clauses in the *Test Set* and get the corresponding metrics.

# %%
print('\nResults on the test set:\n')
testing(params=best_parameters_loaded)
# Out:
# Results on the test set:
#
# Dataset loading...
# Dataset loading completed
#
# Model loading...
#
# Model loading completed
#
#
# Test set metrics:
#
#  Confusion matrix:
#  [[699 637]
#  [ 34  37]]
# F1 Score  : 0.0993
# Accuracy  : 0.5231
# Precision : 0.5211
# Recall    : 0.0549
# ROC AUC   : 0.5043
# Test Loss with final model : 0.5796111920340494

# %% [markdown]
# The following **Figures** show:
# <ol>
# <li>The <b>confusion matrix</b> for the test set-prediction</li>
# <li>The <b>ROC-AUC curve</b> for the test set-prediction</li>
# <li>The <b>precision recall curve</b> for the test set-prediction</li>
# </ol>

# %%
print("\n1.")
display(HTML('<img src="plots/cm.png?%d" height=500 width=500>' % __counter__))
print("2.")
display(HTML('<img src="plots/roc_auc.png?%d" height=450 width=450>' % __counter__))
print("3.")
display(HTML('<img src="plots/pr.png?%d" height=450 width=450>' % __counter__))
# Out:
# 1.
# <img src="plots/cm.png?38918339" height=500 width=500>
# 2.
# <img src="plots/roc_auc.png?38918339" height=450 width=450>
# 3.
# <img src="plots/pr.png?38918339" height=450 width=450>

# %% [markdown]
# Since, as one can notice, ***the results are not very promising using this model and this architecture***, with the current amount of data, the model is not tested on a Test Set from a different data distribution.
